# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get("https://www.amazon.in/gp/bestsellers/books/")                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()     
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)      
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
book=soup.find_all('div',attrs={'class':"_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y"})
Author=soup.find_all('div',attrs={'class':"a-row a-size-small"})
price=soup.find_all('div',attrs={'class':"a-row"})
Rating=soup.find_all('i',attrs={'class':"a-icon a-icon-star-small a-star-small-4-5 aok-align-top"})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
for i in book:
    print(i.text)
    print("\n")
# Out:
# Atomic Habits: The life-changing million copy bestseller [Paperback] James Clear
#
#
# James Clear
#
#
# The Psychology of Money
#
#
# Morgan Housel
#
#
# Energize Your Mind: Learn the Art of Mastering Your Thoughts, Feelings and Emotions
#
#
# Gaur Gopal Das
#
#
# Grandma's Bag of Stories: Collection of 20+ Illustrated short stories, traditional Indian folk tales for all ages for children of all ages by Sudha Murty [Paperback] Sudha Murty
#
#
# Sudha Murty
#
#
# Ikigai: The Japanese secret to a long and happy life [Hardcover] García, Héctor and Miralles, Francesc
#
#
# Héctor García
#
#
# My First Library: Boxset of 10 Board Books for Kids
#
#
# Wonder House Books
#
#
# BlackBook of English Vocabulary March 2023 by Nikhil Gupta Paperback – 22 February 2023
#
#
# Nikhil Kr Gupta
#
#
# Zero to Viral: My Secrets to Going From Zero to Million Followers in a Year | The Ultimate Guide to Content Creation on Social Media
#
#
# Sharan Hegde
#
#
# ...

# %%
for i in Author:
    print(i.text)
    print("\n")
# Out:
# James Clear
#
#
# Paperback
#
#
# Morgan Housel
#
#
# Paperback
#
#
# Gaur Gopal Das
#
#
# Paperback
#
#
# Sudha Murty
#
#
# Paperback
#
#
# Héctor García
#
#
# Hardcover
#
#
# Wonder House Books
#
#
# Board book
#
#
# Nikhil Kr Gupta
#
#
# Paperback
#
#
# Sharan Hegde
#
#
# Hardcover
#
#
# Seep Pahuja
#
#
# Paperback
#
#
# Maple Press
#
#
# Paperback
#
#
# Maple Press
#
#
# Paperback
#
#
# Robert T. Kiyosaki
#
#
# Mass Market Paperback
#
#
# Joseph Murphy
#
#
# Paperback
#
#
# S. Jaishankar
#
#
# Paperback
#
#
# Maple Press
#
#
# Paperback
#
#
# Colleen Hoover
#
#
# Paperback
#
#
# Vashista 360
#
#
# Paperback
#
#
# Gagan Pratap Sir
#
#
# Perfect Paperback
#
#
# Kanchan Keshari
#
#
# Paperback
#
#
# Brijbhoomi Books And Handicrafts
#
#
# Hardcover
#
#
# Gaur Gopal Das
#
#
# Paperback
#
#
# R.D. Sharma
#
#
# Paperback
#
#
# Maple Press
#
#
# Paperback
#
#
# Sudha Murty
#
#
# Paperback
#
#
# Dale Carnegie
#
#
# Paperback
#
#
# Alex Michaelides
#
#
# Paperback
#
#
# Mrunal Patel
#
#
# ...

# %%
for i in price:
    print(i.text)
    print("\n")
# Out:
# Amazon BestsellersOur most popular products based on sales.  Updated frequently.
#
#
#
#
#
#
#
# James Clear
#
#
# 4.6 out of 5 stars 69,931
#
#
# Paperback
#
#
# 14 offers from ₹369.00
#
#
# Morgan Housel
#
#
# 4.6 out of 5 stars 47,101
#
#
# Paperback
#
#
# 65 offers from ₹127.50
#
#
# Gaur Gopal Das
#
#
# 4.6 out of 5 stars 838
#
#
# Paperback
#
#
# 49 offers from ₹180.00
#
#
# Sudha Murty
#
#
# 4.6 out of 5 stars 18,365
#
#
# Paperback
#
#
# 14 offers from ₹170.00
#
#
# Héctor García
#
#
# 4.6 out of 5 stars 45,367
#
#
# Hardcover
#
#
# 29 offers from ₹329.00
#
#
# Wonder House Books
#
#
# 4.5 out of 5 stars 67,755
#
#
# Board book
#
#
# 16 offers from ₹390.00
#
#
# Nikhil Kr Gupta
#
#
# 4.2 out of 5 stars 34
#
#
# Paperback
#
#
# 12 offers from ₹280.00
#
#
# Sharan Hegde
#
#
# 4.2 out of 5 stars 7
#
#
# Hardcover
#
#
# 3 offers from ₹488.00
#
#
# Seep Pahuja
#
#
# 4.2 out of 5 stars 170
#
#
# Paperback
#
#
# 5 offers from ₹699.00
#
#
# Maple Press
#
#
# 4.4 out of 5 stars 6,521
# ...

# %%
for i in Rating:
    print(i.text)
    print("\n")
# Out:
# 4.6 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.3 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.3 out of 5 stars
#
#
# 4.7 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.3 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.7 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# 4.5 out of 5 stars
#
#
# 4.4 out of 5 stars
#
#
# 4.6 out of 5 stars
#
#
# ...
